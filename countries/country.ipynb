# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('country.csv')
dataset
# Out:
#      Serial no       Country         Region  Total Area(sq Km)  Population  \
# 0          198       Vietnam        SE Asia          331212.00    98858950
# 1          131   North Korea        SE Asia          120538.00    26160821
# 2          167   South Korea        SE Asia          100210.00    51784059
# 3           78         India        SE Asia         3287590.00  1428627663
# 4           35         China        SE Asia         9706961.00  1425671352
# ..         ...           ...            ...                ...         ...
# 196        180   Timor-Leste        SE Asia           14874.00     1360596
# 197        182         Tonga        Oceania             747.00      107773
# 198        187        Tuvalu        Oceania              26.00       11396
# 199        195       Vanuatu        Oceania           12189.00      334506
# 200        196  Vatican City  Mediterannean               0.44         518
#
#      Pop. Density (per 1sq. Km)  Male per 100 female  \
# ...

# %%
dataset.describe()
# Out:
#         Serial no  Total Area(sq Km)    Population  \
# count  201.000000       2.010000e+02  2.010000e+02
# mean   101.000000       6.747548e+05  3.997534e+07
# std     58.167861       1.885166e+06  1.475323e+08
# min      1.000000       4.400000e-01  5.180000e+02
# 25%     51.000000       2.077000e+04  1.714671e+06
# 50%    101.000000       1.126220e+05  8.796669e+06
# 75%    151.000000       5.131200e+05  2.887303e+07
# max    201.000000       1.709824e+07  1.428628e+09
#
#        Pop. Density (per 1sq. Km)  Male per 100 female  \
# count                  201.000000           199.000000
# mean                   450.457074           101.199497
# std                   2108.348978            17.747646
# min                      0.138000            81.900000
# 25%                     37.168600            96.550000
# 50%                     95.123600            98.600000
# 75%                    234.588500           101.350000
# max                  21402.705200           266.000000
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 25 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Serial no                                          201 non-null    int64
#  1   Country                                            201 non-null    object
#  2   Region                                             201 non-null    object
#  3   Total Area(sq Km)                                  201 non-null    float64
#  4   Population                                         201 non-null    int64
#  5   Pop. Density (per 1sq. Km)                         201 non-null    float64
#  6   Male per 100 female                                199 non-null    float64
#  7   Male Life expectency (years)                       196 non-null    float64
# ...
